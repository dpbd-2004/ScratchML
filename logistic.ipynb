# %%
# !pip install pandas

# %%
# !pip install seaborn

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13934 sha256=6ee7855684e9ebbd7df1118432165d1efa846ad1b038230431f48d69ff258c76
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\15\0c\b3\674aea8c5d91c642c817d4d630bd58faa316724b136844094d
# Successfully built utils
# ...

# %%
import pandas as pd
import seaborn as sns
from utils import *
import numpy as np

# %%
df= sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
def train_test_split(df,ratio_train=0.8,ratio_test=0.2): # default 80:20  
    if ratio_train + ratio_test > 1:
        print("Thats not how ratios work")
        return None, None
    elif ratio_train == 1:
        return data, None
    elif ratio_test == 1:
        return None,df
    n_rows,n_cols = df.shape
    n_train = int(n_rows* ratio_train)
    n_test = int(n_rows* ratio_test)
    
    shuffled_df = df.sample(frac=1).reset_index(drop=True)
    
    train_df = shuffled_df.head(n_train)
    test_df = shuffled_df.tail(n_test)
    
    return train_df,test_df

# %%
type(train_test_split(df)[0])
# Out:
# pandas.core.frame.DataFrame

# %%
train_test_split(df)
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width     species
#  0             6.4          3.2           5.3          2.3   virginica
#  1             6.3          2.9           5.6          1.8   virginica
#  2             5.4          3.9           1.3          0.4      setosa
#  3             5.5          2.6           4.4          1.2  versicolor
#  4             6.6          3.0           4.4          1.4  versicolor
#  ..            ...          ...           ...          ...         ...
#  115           5.0          3.5           1.6          0.6      setosa
#  116           4.3          3.0           1.1          0.1      setosa
#  117           5.4          3.0           4.5          1.5  versicolor
#  118           4.9          2.4           3.3          1.0  versicolor
#  119           5.9          3.2           4.8          1.8  versicolor
#
#  [120 rows x 5 columns],
#       sepal_length  sepal_width  petal_length  petal_width     species
# ...

# %%
train_df , test_df = train_test_split(df)

# %%
train_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             6.8          2.8           4.8          1.4  versicolor
# 1             5.6          2.7           4.2          1.3  versicolor
# 2             5.7          3.0           4.2          1.2  versicolor
# 3             6.7          3.0           5.0          1.7  versicolor
# 4             5.6          3.0           4.1          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 115           5.9          3.0           4.2          1.5  versicolor
# 116           6.3          2.7           4.9          1.8   virginica
# 117           5.8          4.0           1.2          0.2      setosa
# 118           6.8          3.0           5.5          2.1   virginica
# 119           4.9          3.1           1.5          0.1      setosa
#
# [120 rows x 5 columns]

# %%
test_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 120           7.3          2.9           6.3          1.8   virginica
# 121           6.9          3.1           4.9          1.5  versicolor
# 122           6.3          2.3           4.4          1.3  versicolor
# 123           5.3          3.7           1.5          0.2      setosa
# 124           6.2          3.4           5.4          2.3   virginica
# 125           4.7          3.2           1.6          0.2      setosa
# 126           6.7          2.5           5.8          1.8   virginica
# 127           5.1          3.8           1.9          0.4      setosa
# 128           6.1          2.8           4.7          1.2  versicolor
# 129           6.1          2.8           4.0          1.3  versicolor
# 130           5.8          2.7           3.9          1.2  versicolor
# 131           5.6          2.5           3.9          1.1  versicolor
# ...

# %%
class logistic_regression:
    def __init__(self, learning_rate=0.001,n_iters=1000):
        self.lr = learning_rate
        self.epochs = n_iters
        self.weights = None
        self.bias = None
    
    def _sigmoid(x): # for internal use only 
        return 1 / (1 + np.exp(-x))
    
    def calc_loss(self,y_true,y_pred):
        epsilon = 1e-9
        y1 = y_true*np.log(y_pred + epsilon)
        y2 = (1-y_true)*np.log(1-y_pred+epsilon)
        return -np.mean(y1+y2)
    
    def feed_forward(self,X):
        Z = np.dot(X,self.weights) + self.bias
        A = self._sigmoid(Z)
        return A
    
    def fit(self, X, y):
        n_samples, n_features = X.shape
        
        self.weights = np.zeros(n_features)
        self.bias = 0
        
        for _ in range(self.epochs):
            A = self.feed_forward(X)
            self.losses.append(calc_loss(y,A))
            dz = A - y
            
            dw = (1/n_samples)*np.dot(X.T,dz)
            db = (1/n_samples)*np.sum(dz)
            
            self.weights -= self.lr*dw
            self.bias -= self.lr*db
    
    def predict(self,X):
        threshold = 0.5
        y_hat = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(y_hat)
        y_predicted_cls = [1 if i > threshold else 0 for i in y_predicted]
        
        return np.array(y_predicted_cls)

# %%
X_train, y_train = train_df[["sepal_length","sepal_width","petal_length","petal_width"]],train_df["species"]

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             6.8          2.8           4.8          1.4
# 1             5.6          2.7           4.2          1.3
# 2             5.7          3.0           4.2          1.2
# 3             6.7          3.0           5.0          1.7
# 4             5.6          3.0           4.1          1.3
# ..            ...          ...           ...          ...
# 115           5.9          3.0           4.2          1.5
# 116           6.3          2.7           4.9          1.8
# 117           5.8          4.0           1.2          0.2
# 118           6.8          3.0           5.5          2.1
# 119           4.9          3.1           1.5          0.1
#
# [120 rows x 4 columns]

# %%
y_train
# Out:
# 0      versicolor
# 1      versicolor
# 2      versicolor
# 3      versicolor
# 4      versicolor
#           ...
# 115    versicolor
# 116     virginica
# 117        setosa
# 118     virginica
# 119        setosa
# Name: species, Length: 120, dtype: object

# %%
X_test, y_test = test_df[["sepal_length","sepal_width","petal_length","petal_width"]],train_df["species"]

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 120           7.3          2.9           6.3          1.8
# 121           6.9          3.1           4.9          1.5
# 122           6.3          2.3           4.4          1.3
# 123           5.3          3.7           1.5          0.2
# 124           6.2          3.4           5.4          2.3
# 125           4.7          3.2           1.6          0.2
# 126           6.7          2.5           5.8          1.8
# 127           5.1          3.8           1.9          0.4
# 128           6.1          2.8           4.7          1.2
# 129           6.1          2.8           4.0          1.3
# 130           5.8          2.7           3.9          1.2
# 131           5.6          2.5           3.9          1.1
# 132           4.4          3.0           1.3          0.2
# 133           5.0          3.4           1.5          0.2
# 134           5.7          2.8           4.1          1.3
# ...

# %%
y_test
# Out:
# 0      versicolor
# 1      versicolor
# 2      versicolor
# 3      versicolor
# 4      versicolor
#           ...
# 115    versicolor
# 116     virginica
# 117        setosa
# 118     virginica
# 119        setosa
# Name: species, Length: 120, dtype: object

# %%
regressor = logistic_regression(learning_rate=0.0001, n_iters=1000)
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 regressor = logistic_regression(learning_rate=0.0001, n_iters=1000)
# ----> 2 regressor.fit(X_train, y_train)
#       3 predictions = regressor.predict(X_test)
#
# Cell In[71], line 29, in logistic_regression.fit(self, X, y)
#      26 self.bias = 0
#      28 for _ in range(self.epochs):
# ---> 29     A = self.feed_forward(X)
#      30     self.losses.append(calc_loss(y,A))
#      31     dz = A - y
#
# Cell In[71], line 19, in logistic_regression.feed_forward(self, X)
#      17 def feed_forward(self,X):
#      18     Z = np.dot(X,self.weights) + self.bias
# ---> 19     A = self._sigmoid(Z)
#      20     return A
#
# TypeError: logistic_regression._sigmoid() takes 1 positional argument but 2 were given
